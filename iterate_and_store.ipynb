# %%
import pandas as pd
from pathlib import Path

# %%
in_dir_calc = Path(r'Z:\Reporting\Radio vs Sales New\calcs')
in_file_calc = [i for i in in_dir_calc.iterdir()][-1]

# %%
in_dir_report = Path(r'Z:\Reporting\Radio vs Sales New\reports')
in_file_report = [i for i in in_dir_report.iterdir()][-1]

# %%
# df_report = pd.read_excel(
#     in_file_report, 
#     sheet_name='Christian', 
#     skiprows=[0,1, 2, 3],
#     header=[0, 1, 2]
#     )
# df_report.head()

# %%
df = pd.read_excel(in_file_calc, sheet_name=['Charts', 'Digital Songs', 'Audio On-Demand', 'Song Consumption', 'Trend Reports'])

# %%
# df['Trend Reports']

# %%
# for k, v in df.items():
#     print(k)
#     display(v.head(1))
#     print(v.shape)
#     print()

df_charts = df['Charts'].drop('Unnamed: 0', 1).reset_index(drop=True)
df_charts_christian = df_charts[df_charts['Chart'] == 'Christian Airplay']
df_charts_christian = df_charts_christian[df_charts_christian['WK'] == 202233]

df_digital_songs = df['Digital Songs'].drop('Unnamed: 0', 1).reset_index(drop=True)
df_audio_on_demand= df['Audio On-Demand'].drop('Unnamed: 0', 1).reset_index(drop=True)
df_song_consumption = df['Song Consumption'].drop('Unnamed: 0', 1).reset_index(drop=True)
df_trend = df['Trend Reports'].drop('Unnamed: 0', 1).reset_index(drop=True)
# Out:
# C:\Users\KamilcS\AppData\Local\Temp\ipykernel_23336\2132552077.py:7: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df_charts = df['Charts'].drop('Unnamed: 0', 1).reset_index(drop=True)
# C:\Users\KamilcS\AppData\Local\Temp\ipykernel_23336\2132552077.py:11: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df_digital_songs = df['Digital Songs'].drop('Unnamed: 0', 1).reset_index(drop=True)
# C:\Users\KamilcS\AppData\Local\Temp\ipykernel_23336\2132552077.py:12: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df_audio_on_demand= df['Audio On-Demand'].drop('Unnamed: 0', 1).reset_index(drop=True)
# C:\Users\KamilcS\AppData\Local\Temp\ipykernel_23336\2132552077.py:13: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df_song_consumption = df['Song Consumption'].drop('Unnamed: 0', 1).reset_index(drop=True)
# C:\Users\KamilcS\AppData\Local\Temp\ipykernel_23336\2132552077.py:14: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df_trend = df['Trend Reports'].drop('Unnamed: 0', 1).reset_index(drop=True)

# %%
df_christian_filtered = df_trend[
    (df_trend['Nielsen_ID'].isin(df_charts_christian['Nielsen_ID'])) &
    (df_trend['week'] == 33)].reset_index(drop=True)

# %%
df_christian_filtered.Genre.unique()
# Out:
# array(['Christian, Christian/Gospel', 'Alt. Rock, Rock',
#        'Christian, Christian/Gospel, Gospel', 'Christian/Gospel', nan,
#        'Alt. Rock, Hard Rock, Rock', 'Christian/Gospel, Gospel'],
#       dtype=object)

# %%
df_christian_filtered.groupby(['Activity', 'Song']).value.sum().index
# Out:
# MultiIndex([(          'Airplay Audience',               'A Disappearing Act'),
#             (          'Airplay Audience',                    'All My Praise'),
#             (          'Airplay Audience',                           'Always'),
#             (          'Airplay Audience', 'Authority (In The Name Of Jesus)'),
#             (          'Airplay Audience',                           'Beggin'),
#             (          'Airplay Audience',                     'Build A Boat'),
#             (          'Airplay Audience',                           'Church'),
#             (          'Airplay Audience',                 'Don't Lose Heart'),
#             (          'Airplay Audience',                      'Fill My Cup'),
#             (          'Airplay Audience',                  'For All My Life'),
#             ...
#             ('Total Streaming Programmed',     'Thank God For Sunday Morning'),
#             ('Total Streaming Programmed',                        'Thank You'),
#             ('Total Streaming Programmed',                     'The Goodness'),
#             ('Total Streaming Programmed',                      'The Healing'),
#             ('Total Streaming Programmed',                 'Then Christ Came'),
#             ('Total Streaming Programmed',                 'There Is Freedom'),
#             ('Total Streaming Programmed',                'We All Need Jesus'),
#             ('Total Streaming Programmed',                   'What He's Done'),
#             ('Total Streaming Programmed',                         'Who I Am'),
#             ('Total Streaming Programmed',                  'Won'T Let Me Go')],
#            names=['Activity', 'Song'], length=474)

# %%
df_charts = df['Charts']

christian_ids = df_charts[(df_charts['Chart'] == 'Christian Airplay') & (df_charts['WK'] == 202233)]

christian_ids = df_trends[df_trends['Nielsen_ID'].isin([christian_ids])]

# %%
df_charts['Chart'].unique()
# Out:
# array(['Adult Contemporary', 'Adult R&B Airplay', 'Adult Pop Airplay',
#        'Alternative Airplay', 'Christian Airplay', 'Country Airplay',
#        'Latin Airplay', 'Mainstream R&B/Hip-Hop Airplay',
#        'Mainstream Rock Airplay', 'Pop Airplay', 'Rhythmic Airplay',
#        'Smooth Jazz Airplay', 'Adult Alternative Airplay'], dtype=object)

# %%
df_trends = df_calcs['Trend Reports']
# 
christian_ids = df_charts[(df_charts['Chart'] == 'Christian Airplay') & (df_charts['WK'] == 202233)]['Nielsen_ID']
christian_ids
# Out:
# 852    169459448
# 853    169306078
# 854    155136170
# 855    177826997
# 856    150195130
# 857    165330256
# 858    174032566
# 859    157847134
# 860    170967320
# 861    172154680
# 862    171548005
# 863    174698450
# 864    170485019
# 865    177482570
# 866    155612371
# 867    171338474
# 868    169446744
# 869    147783172
# 870    167910949
# 871    180232432
# 872    173610689
# 873    176878407
# 874    175735537
# 875     92770734
# 876    171670616
# 877    152397671
# 878    156827887
# 879    174171922
# 880    178289345
# 881    172948860
# 882    173610687
# 883    178858018
# 884    181342527
# 885    171892423
# 886    146597417
# 887    175204396
# 888    132479464
# 889    168363080
# 890    179747863
# 891    178858011
# 892    170969038
# 893    160045361
# 894    166244876
# 895    174835235
# 896    173509380
# 897    178646002
# 898    176423427
# 899    176423426
# 900    179841676
# 901    177926010
# Name: Nielsen_ID, dtype: int64

# %%
df_charts[df_charts["Nielsen_ID"].isin(christian_ids)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Nielsen_ID, Title, Artist, TP_Spins, Chg_Spins, LP_Spins, Stations, Adds, TP_Audience, Chg_Audience, LP_Audience, TP_Stream, TW_Rank, WK, Chart, label]
# Index: []

# %%
# df_trends[(df_trends['year'] == 2022) & (df_trends['week'] == 33)].groupby(['Activity', 'year','week'])[['value']].mean().style.format(precision=0, na_rep=0, thousands=",")


# christian_ids[(christian_ids['year'] == 2022) & (christian_ids['week'] == 33)].pivot_table(
#     index=[
#         'Artist', 
#         # 'Song'
#         ], 

# columns= [
#     'Activity'], 
#        values = 'value',
#        aggfunc=sum)

christian_ids
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Artist, Song, Release_Date, Label_Abbreviation, Genre, Core_Genre, Date_Selected, Release_Age, Market, Activity, Retailer/Provider, ISRC/Barcode, Airplay_Format, date, year, week, value, Nielsen_ID]
# Index: []

# %%
df_trends[(df_trends['year'] == 2022) & (df_trends['week'] == 33)].groupby(['Activity'])[['value']].mean().style.format(precision=0, na_rep=0, thousands=",").index
# Out:
# Index(['Airplay Audience', 'Airplay Spins', 'Digital Song Sales',
#        'Songs w/SES On-Demand', 'Songs w/SES On-Demand Audio',
#        'Streaming On-Demand Audio', 'Streaming On-Demand Video',
#        'Streaming Programmed Audio', 'Streaming Programmed Video',
#        'Total Streaming On-Demand', 'Total Streaming Programmed'],
#       dtype='object', name='Activity')

# %%
df_trends.Song.unique()
# Out:
# array(['Running Up That Hill', 'Easy On Me', 'Who I Am', 'Bam Bam',
#        'Bad For Me', 'Brighter Days', "Don't Lose Sight",
#        'God Is In This Story', 'Turn Up The Sunshine', 'Believe For It',
#        'Going Crazy', 'Heat Waves', 'Fingers Crossed', 'Higher', 'Hands',
#        'Beggin', 'Me On Your Mind', 'Stay', 'All She Wanna Do', 'Lil Bit',
#        'Until I Found You', 'Dandelions', 'Build A Boat',
#        "Wildest Dreams (Taylor's Version)",
#        'Mr. Perfectly Fine (From The Vault)',
#        "You Belong With Me (Taylor's Version)",
#        "Drunk (And I Don'T Wanna Go Home)", "I Don'T Want To Miss It",
#        'Am Gold', "(I'm Gonna) Run Away (Acoustic)", 'Woman',
#        'Jesus Is Coming Back', 'Numb Little Bug', 'Born To Die',
#        "I Ain't Worried", "She's All I Wanna Be", 'If This Is Goodbye',
#        'Thank God For Sunday Morning', "When You're Gone", 'Boyfriend',
#        'For God Is With Us', 'Same Heartbreak Different Day',
#        'Sunday Sermons', 'Follow You', 'Bones', 'Sweet',
#        'Even At My Worst', 'Unstoppable', 'Shivers', 'One Life',
#        'As It Was', 'About Damn Time', 'Egypt', 'In The Clouds', '2step',
#        'Fill My Cup', 'Enemy', 'Easy', 'Go', 'See Me Through It',
#        'Hold My Hand', 'Left And Right', 'Cold Heart', 'Irrelevant',
#        'Light Up The Night', 'Like A Virgin (7 Version) (2022 Remaster)',
#        'Peace Joy Love', 'Me Myself & I', 'My God Is Still The Same',
#        "Things That I'M Afraid Of", 'Thousand Miles', 'Cooped Up',
#        'Stand In Faith', 'Something to Someone', 'Hymn Of Heaven',
#        'Battle Belongs', 'House Of The Lord',
#        'Help Is On The Way (Maybe Midnight)', 'The Goodness',
#        'We All Need Jesus', 'Lie', 'Next To Me',
#        'The Joker And The Queen', 'Hurry Up And Wait', 'I Will Carry You',
#        'BREAK MY SOUL', '2 Be Loved (Am I Ready)', "DON'T YOU WORRY",
#        'INDUSTRY BABY', 'Easy Lover', 'In The House', 'Good God Almighty',
#        'Need To Know', 'Get Into It (Yuh)', 'Summer Song', 'Potion',
#        'Be Alright', 'In Jesus Name (God Of Possible)', 'For The Good',
#        'Back Together Again',
#        "We Are Never Ever Getting Back Together (Taylor's Version)",
#        "22 (Taylor's Version)", 'Sway', 'Jireh',
#        "Maybe You're The Problem", 'Jump', "We Don't Talk About Bruno",
#        'Heart Of The Father', 'That Old Flame', 'Early In The Morning',
#        'Hot Shit', 'I Think I Like You', 'There Is Freedom',
#        "Tough Get Goin'", 2020, 'In A Minute',
#        'I Like You (A Happier Song)', 'First Class', 'Late At Night',
#        'Saved My Life', 'Impossible', '(Wonder Working)', 'Hello 2 You',
#        'Same God', 'Summertime In NYC', 'The Commission', 'Mean Girls',
#        'New Creation', 'Wasted On You', 'Glimpse Of Us', 'Out Of Time',
#        'Gratitude', "Candie's Dance", 'Moscow Mule', 'Wait For U',
#        'How Far', 'Never Say Never', 'Promise Keeper', 'Chosen',
#        "Don't Lose Heart", 'Lift My Eyes', 'Trillions', 'Good Feeling',
#        'Tell Me You Love Me', 'Unloyal', 'Daylight', "Don't Rush",
#        'Never Knew Love', 'Baby Boo', 'Weary Traveler', 'Be Over',
#        'Pour Your Spirit Out', 'Get To You', 'Sweet Release',
#        'Cherry Sorbet', 'Make Me Say It Again Girl', "Love's Train",
#        'Essence', 'Slow', "Don'T Love Me", 'Fake It', 'Complete Mess',
#        'My Best', 'Right On Time', "Look What You've Done", 'Lessons',
#        'Woman Like Me', 'The Healing', 'Stand', 'Turnt Up Tonight',
#        'We (Warm Embrace)', 'Caravan Of Love', 'Footprints Of An Angel',
#        'Gospel Song', 'One More Night', 'Substance', 'Joyful',
#        'My Portion', 'Finesse', 'Patience', 'Carolina', 'Always',
#        'Love Is Everything We Need', 'Good Ol Lovin', 'Slide', 'My Peace',
#        'Satisfied Feat. Smokie Norful (Live)', 'Miracle Power',
#        'Exchange', 'For Love', 'Gotta Move On', 'Never Let Me Down',
#        'Keep On Rollin', 'Hate Our Love', 'Honey', 'Nothing Better',
#        'Take A Dose', 'All Of My Help', 'Breathe', 'Tomorrow Can Wait',
#        'Call Me Everyday', 'Gone', 'My Jesus', 'Here With Me',
#        'Hurt Me So Good', 'Amazing', 'Positive', 'After Last Night',
#        'Wild Side', "No Stoppin' Us", 'Numb', 'Jukebox Lover',
#        'Choosey Lover', 'Cafe', 'Soul Ties', 'Baddest',
#        'Victoria’s Secret', 'All In Your Hands',
#        'Vegas (From The Original Motion Picture Soundtrack Elvis)',
#        "You'Re The One", 'Dress', 'SUPERMODEL', 'Lost Without You',
#        'Sure As', 'See Through Love', 'Grand', 'Thankful', 'Flowers',
#        'Snap', 'Take Me Away', 'All The Way',
#        'Music For A Sushi Restaurant', "You're Mines Still", 'Peru',
#        'Pretty Lady', 'Come Back To Me', 'You Proof', 'She Likes It',
#        "Let's Take A Ride", "You Don'T Need It", 'He Did It For Me',
#        'Heartfirst', 'West Coast', 'Lie Again', "Don'T Play With Love",
#        'Massive', 'How Will I Know', "I Won'T Hurt You", 'Free Mind',
#        'Beautiful Lies', 'Come By Here', 'Hallelujah', 'Have Mercy',
#        'Where Are You Now', 'Your Presence Is A Gift',
#        'Living My Best Life', 'Betty (Get Money)', 'Summer Renaissance',
#        'Church Girl', 'Yeah, I Like You', 'Good Love',
#        'Color Outside The Lines', 'Overpass Graffiti',
#        'Only Wanna Be With You', 'My God',
#        "I Knew You Were Trouble (Taylor's Version)", "Let's Do It Again",
#        '10 Things I Hate About You', "Still Gon' Trust", 'Bad Habit',
#        'Angel (Extended Mix)', 'Envy', 'Best Friend', 'About You',
#        'Great', 'Spinning The Truth Around', 'Sweetest Pie',
#        'up at night', 'He Kept Me', "Devil Doesn't Bargain", 'Chance?',
#        'When I Pray', "Can't Stop Us Now", 'Call', 'Lonely People',
#        'I Want You',
#        'Nothing Else Matters (Instead Of Complaining, Praise Him)',
#        'Lucky', 'Sun Keeps On Shining', 'Unconditional I (Lookout Kid)',
#        "What's The Trick?", 'Endlessly', 'Records', 'Blood Runs Red',
#        'High Again', 'Tippa My Tongue', 'These Are The Ways',
#        'Black Summer', 'Wet Dream', 'Bad Decisions',
#        "I Don't Like Myself", 'Natural Born Killer', 'So Called Life',
#        'Lifetime', 'No Apologies', 'Boy', 'Stay Out Of It',
#        'Part Of The Band', 'Roadkill', 'All Comes Crashing', 'Settling',
#        'Raised By Wolves', 'Strangers', 'Giants', 'Ramon Ayala',
#        'Clarity', 'Fait Accompli', 'Here To Forever', 'Better Alone',
#        "It Ain'T Over", 'Times Like These', 'The Foundations Of Decay',
#        'The Shower Scene', 'More Than Machines',
#        'Vogue (Single Version) (2022 Remaster)', 'Behind Your Walls',
#        'Take It Back', 'Wake Up', "I Won't", 'Compliance',
#        "Life's Been Good", 'Make You Say', "Don't Let The Light Go Out",
#        'Middle Of A Breakup', 'Cracker Island', 'Sail Away', 'Cleopatra',
#        'Telepatia', 'Happy Face', 'Hey You',
#        'Running Back (Trying To Talk To You)', 'Something Loud',
#        'Then It All Goes Away', 'Pure/Honey', 'Alien Superstar',
#        'We Are All We Need', 'Scared Together', 'Scream!', 'Alpha Zulu',
#        'Keeps Me Going', 'Border', 'Charlie', 'These Are The Days',
#        'The Game', 'Voices In My Head', "I've Been Thinking",
#        'I Cry Jesus', 'Survive', 'Selfish Soul', 'Wonderful Life',
#        'Insomnia', 'Rockstar', 'LION', "What He's Done", 'I Know You Can',
#        'Rest On Us', 'On And On', 'Thank You', 'Brad Pitt', 'Plans',
#        'Dead Inside', 'Faithful', 'If The Lord Builds The House',
#        'Sunburn', 'Master Of Puppets', 'Good Mood', 'For All My Life',
#        "De'ja' Vu", 'Entropy', 'Bad Things', "I'm So Blessed",
#        datetime.time(10, 36), "Firm Foundation (He Won't)", 'God You Are',
#        'Perfectly Loved', 'Burning', 'Soul Worth Saving',
#        'Then Christ Came', 'Blacklight Shine', 'Honey In The Rock',
#        'How You Love Me', "Won'T Let Me Go", 'God Really Loves Us',
#        'Do Your Worst', 'Wicked Ways', "Glory I Couldn'T See",
#        'Hayloft Ii', "That's Where I Am", 'Nail Scarred Hands',
#        'Spitting Off The Edge Of The World', 'Summer In New York',
#        'Silence Is Golden', 'All My Praise', 'Same Team',
#        'Without Your Love', 'Now Here', 'A Disappearing Act', 'Church',
#        'I See Grace', 'Patient Number 9', 'Godspeed', 'Hold You Tight',
#        'Tired Of Winning', 'All The Things I Hate About You',
#        'Shackles (Praise You)', 'Eye Of The Storm', 'No Matter What',
#        'Joy In The Morning', 'Good Morning Mercy', 'I Believe (Live)',
#        "I'Ll Fight For You", 'Heathens/Stranger Things',
#        'Authority (In The Name Of Jesus)', 'This Is My Song',
#        'Heart Like A Truck', 'Wishful Drinking', 'Every Victory',
#        'Fear Is Not My Future', 'With A Woman You Love', 'Champion',
#        'Revival', 'Yahweh (No One)', 'Soul', "Country'D Look Good On You",
#        'Brown Eyes Baby', 'Fall In Love', 'Holy Water', 'Joy Of My Life',
#        'Rest For Your Soul', 'Too Good To Not Believe',
#        'What My World Spins Around', 'Good Day For Living',
#        "It's About Time", 'No Body', "That's The Power", 'Gold',
#        'Miracle In The Works', 'At The End Of A Bar',
#        'She Had Me At Heads Carolina', 'Half Of Me', 'My Bar',
#        "Where I'm Standing Now", 'Into The Wild', 'Goodness Of God',
#        '5 Foot 9', 'The Heat', 'Human', 'Down Home', 'Homecoming (Live)',
#        'My Testimony (Live)', 'Everything And More', 'Out In The Middle',
#        "What I'm Waiting For", 'Arms Of Jesus', 'Human Nature',
#        'What A Good God', 'Like I Love Country Music', 'Perfection',
#        'You', "Don't Come Lookin'", 'First Things First',
#        'Last Night Lonely', 'Take My Name', 'Look What God Has Done',
#        'God Turn It Around', 'Son Of A Sinner', 'We Praise You',
#        'Party Mode', "What He Didn'T Do", "You Didn't",
#        "That's What Tequila Does", 'Truth About You', 'No Hard Feelings',
#        'Whiskey On You', 'Healer', 'Living Water', 'Make Room',
#        'Country On', 'Water Under The Bridge', 'Hills & Horizons',
#        'The Kind Of Love We Make', 'Damn Strait', 'Alive', 'Ghost Story',
#        'Pick Me Up', "Love Won't Let Go", 'We Praise You (Live)',
#        'Coming Back', 'Wild As Her', 'Out Of Nowhere', 'Tequila For Two',
#        'Hell Yeah', 'Longneck Way To Go', 'Heart Of A Small Town',
#        "I Can'T Decide", 'Crazy One More Time (2022)', 'Memory',
#        'Te Felicito', 'Beach Boys', 'Mind On You', '50 Y Cincuenta',
#        'Son Of A', 'A Veces Bien Y A Veces Mal', 'How Is She',
#        'How You Make A Man', 'El 30 De Febrero', 'Baile Con Mi Ex',
#        'Boy Like Me', "Everything She Ain't", 'Man Made',
#        'Doing Life With Me', 'Rock And A Hard Place', 'Left You For Me',
#        'Something In The Orange', 'Girl In Mine', 'La Luna De Miel',
#        'Country In My Soul', 'Just Drive', 'Note To Self',
#        'If He Wanted To He Would', 'Summer State Of Mind', 'Country Can',
#        'How It Oughta Be', 'Try Losing One', 'JGL', 'La Bachata',
#        'Easy Tonight', 'Handle On You', 'Found It In You',
#        'Never Til Now', 'Buy A Girl A Drink', "Y'All Life",
#        'Songs About You', 'Downtown Baby',
#        "Catching Up With An Ol' Memory", 'Me Porto Bonito', 'Pegao',
#        'Salt, Lime & Tequila', 'Anything Like You Dance',
#        'Loud and Heavy', 'Last Name On It',
#        "Sounds Like Something I'D Do", 'Worth A Shot',
#        'Every Single Summer', 'Desesperados', 'Mayor Que Usted',
#        'Get Down Like That', 'Me On You', 'Death And Taxes', 'Pass It On',
#        'Nazareno', 'Provenza', 'Mamiii', 'Dates In Pickup Trucks',
#        'Sensual Bebe', 'Nobody Knows', 'El Reemplazo', 'Strange',
#        'Envolver', 'Pickup', 'Sundays In The South', 'Glass',
#        'Partido En Dos', 'Lo Mejor Que Hay En Mi Vida', 'Nada De Nada',
#        'En Dias Como Estos', 'Problemas', 'En El Radio Un Cochinero',
#        'Brindo', 'Ya No Somos Ni Seremos', 'Vivo En El 6',
#        'Hay Que Hacer Dinero', 'La Loto', 'Tv', 'Layback',
#        'Miranos Ahora', 'Peligro', 'La Boda Del Huitlacoche',
#        'Soldado Caido', 'Fuera De Servicio', 'eScoRpiOn:)',
#        'Ninguna Mujer', 'Nunca Y Pico', 'Nos Comemos Vivos',
#        'Si Me Duele Que Duela', 'Se Acabo', 'Hot', 'Normal', 'El Negrito',
#        'La Profecia', 'La Llevo Al Cielo', 'A Veces', 'Somos Iguales',
#        'Nos Comemos', 'AEIOU', 'Te Amo Y Punto', 'Nivel De Perreo',
#        'Pa Que Tu Me Llamas', 'Tus Lagrimas', 'Fuerte No Soy',
#        'Que Llore, Que Llore', 'Despecha', 'Que Digan Lo Que Digan',
#        'Calidad', 'Llorar Y Llorar', 'Llueve', 'Nunca Dudes En Llamarme',
#        'Despues De La Playa', 'Titi Me Pregunto', 'El Infierno',
#        'La Fiesta', 'Muero', 'Dile A Tu Orgullo (Yaki Fest 2021)',
#        'Respirar', 'Quiero Quemar La Pista', 'Te Voy A Conquistar',
#        'Si Te Preguntan', 'Rumbaton', 'La Mata Sigue Dando', 'Suelta',
#        'El Teke Teke', 'Party', 'Modo Crudo', 'Berlin',
#        'Todavia Te Espero', 'Al Sabor Del Champagne', 'Ya Acabo',
#        'Pa Que Sude (Gonna Make You Sweat)', 'Facil De Convencer',
#        'Noche De Teteo', 'Ya Lo Pense Mejor', 'Me Falta Un Pecado',
#        'Amor Perfecto', 'A Ver Como Le Haces', 'Cuentame',
#        'Te Llore Un Rio', 'Cash In Cash Out', "What's My Name",
#        'Billie Eilish.', 'Ski', 'All Mine', 'Pressurelicious',
#        'Super Gremlin', 'Usain Boo', 'If I Get Caught', 'Cater', 'X',
#        'I Hate U', 'Swangin (Chad)', 'Down Bad', 'Sticky', 'How',
#        'True Love', 'Snatched', 'Friends', 'Honest', 'Forever Tippin',
#        'Drop', 'Steppers', 'Who Want Smoke?', 'The Highs & The Lows',
#        "F.N.F. (Let's Go)", 'Die Hard', 'Pop Out', '1, 2, 3', 'Last Last',
#        'Die Young', 'Hotel Lobby (Unc And Phew)', 'Mind Yo Business',
#        'Fair Trade', 'Booty', 'Sleazy Flow', 'Iffy', 'Another',
#        'Silent Hill', 'Banking On Me', 'Save Me', 'Scooch',
#        "Can't Stop Won't Stop", 'Sunshine', 'Jimmy Cooks',
#        'Staying Alive', 'Lost Me', 'What Happened To Virgil',
#        'Super Freaky Girl', "It Doesn'T Matter", 'Plan B', 'Waddup',
#        'Supercharge', 'Over', 'Right On', 'Doja', 'Magic', 'Bestie',
#        'Love You Better', "See Wat I'm Sayin", 'Rock Out', 'Dolce',
#        'Say Yea', 'Toxic', 'Do Not Disturb', 'Hall Of Fame',
#        'Me Siento A Todo Dar', 'Feel Better', 'Paper Route', 'My Dawg',
#        'Quien Se Apunta', "Ain't My Thot", 'Crows', 'Let Me In',
#        'Heart To Stone', 'Black Rhino', 'Nevermore', 'Omens', 'Spillways',
#        'Secret', 'What If', 'The Dying Song (Time To Sing)', 'Yen',
#        'To The Moon', 'Cut The Cord', 'Becoming', 'Faded Out',
#        'Bloodline', 'Make Believe', 'Revolution', 'Soldier On!',
#        'Hurts Like Hell', 'Will Of The People', 'Winless War',
#        'Take What You Want', 'A Little Bit Of Love',
#        'All My Favorite Songs', 'Baba', 'When We Were Young', 'Glitch',
#        'No More Tears To Cry', 'Ringin In My Head', 'The Funeral',
#        'Unhallowed', 'The Truth',
#        'Stop Beating On My Heart (Like A Bass Drum)', 'Riptide', 'U-Digg',
#        'Money', 'Night Stalkers', 'Blood Runs Cold', 'Had To Know',
#        'Waiting On The Sky To Change', 'Classless Act', 'Rain Down',
#        'Masterpiece', 'Still Sinking', 'Blow', 'City Of The Dead',
#        'You Made Me Want To Live', 'Get All Up In It', 'Miracle',
#        'Worst Is On Its Way', 'I Still Burn', 'When I Get Paid',
#        'Body Bag', 'The Retaliators Theme (21 Bullets)',
#        'Welcome To The Chaos', 'Silver Tongue', 'Ice Cold',
#        'Just Pretend', 'Cage', 'Dial Tone', 'Degradation Rules',
#        'Heartache', 'Just Say That', 'In Our Blood', 'Afterlife',
#        'Set You Free', 'Escape', 'Sinner', 'Loser', 'Above It All',
#        'Saturday Night', '100 Little Deaths', 'Ratcatcher',
#        'Captain Diamond', 'Run', 'Friday @5', 'Catalina Nights',
#        'Die For You', 'Calm Down', 'City Lights', 'Scared Money',
#        'This Is The Good One', 'Dance Beat', 'Jiggle Jiggle',
#        'Business As Usual', 'Stay With Me', 'No Stoppin', 'Highway 5',
#        'No Love', 'Drive', 'Step Into Love', 'Wait', 'On The Road',
#        'Dr. Doolittle', "What I'M Waiting For", 'Song Of May', 'Closer',
#        "Life's Too Short", 'Die First', 'Step To This',
#        'Family Affair (Dance For Me)', 'Following The Sun', 'Her',
#        'Honestly', 'Cheated', 'Time To Shine', 'Covent Garden',
#        'Valley Of Lies', 'Someone To Blame', 'I Do', 'Shake It',
#        'Highway 10', 'Real Talk', 'Ready Or Not', 'Angelic Chimes',
#        "I'll Be The One", 'Deep Down', 'No Mas', 'Scorpio', 'In My Head',
#        'Handsomer', 'Ferrari', 'Shadow Of Doubt', 'Secret Sauce',
#        'Bad Habits', 'Thrill Ride', 'What Would You Do?', "Workin'",
#        'Pink Venom', 'Sistas', 'Come Back Home', 'Ocean Drive', 'Maniac',
#        'Bring It Back', 'Are You Entertained', 'Good On You', 'That Girl',
#        'Summer Nights', 'In Too Deep', 'Jazz Party',
#        'Wrapped Around Your Finger', 'Summer In Blue',
#        'The Color Of Love', 'Lost', 'Hot In It', 'Cake', 'Lavish',
#        'One Step Ahead', 'The Otter', 'What Is Hip?', 'Hospital',
#        'Dot-d-Dah!', 'My Babe', 'Ticket To Pittsburgh',
#        'What Kind Of World', 'Force', 'We As One', 'Lemon Tree',
#        'Let It Flow', 'Mistakes', 'Captured By Love', 'Miles And Miles',
#        'Ride With Me', 'New Heights', 'Coupe de Ville', 'Free',
#        'Move Ahead', 'Come Party With Me', 'Hydra',
#        'That Cool Groovy Beatnik Jazz', 'Show Me', "Can't Hurry Love",
#        "Freddie's Groove", 'Old Friends', 'Nothing Ever Hurt Like You',
#        'Boom', 'In Position', 'You And Me On The Rock', 'Journey To Love',
#        'In His Vision', 'Hustle', 'Love Planet', 'Play', 'Synchronize',
#        'Blue Sphere', "Let's Get Up", 'A Song For Peace',
#        'Keep The Faith', "Let's Get Down Tonight", 'One More Kiss',
#        'Stomp', 'First High', 'Heart Of Mine', 'Chances', 'Say What',
#        'Electric Shock', 'Dream Again', 'Footsteps In The Dark',
#        "Q's Vibe", 'Paradigm Shift', 'TSF', "Chillin' Out",
#        "That's My Jam", 'Fika Talk', "Ain't No Sunshine", 'Summertime',
#        'Intentional', 'Deep Into You', 'Quiet Storm', 'Perfect Timing',
#        'Right On Key', 'I Know', 'Flow', 'Melody Man', "Let's Rewind",
#        'Easy Street', 'Broken Promises', 'Leather Jacket', 'Turn Me Up!',
#        'Road Trip', 'Make A Picture', 'Hurts (But It Goes Away)',
#        'Soul Sweet Song', 'High Priestess', 'Pick It Up',
#        'Anything But Me', 'Roman Holiday', 'Yellow', 'Speeding 72',
#        'Brighter Day', 'Runner', 'So Typically Now',
#        'When You Lose Someone', 'Stick Season', 'A Nocturnal Heresy',
#        'Rock Bottom', 'Blah Blah Blah', 'Shotgun', 'Vault Of Heaven',
#        'I Was Neon', 'Hawk For The Dove', 'Wretched',
#        'Hollywood Forever Cemetery', 'A.M. Radio', 'Spit Of You',
#        'Cheers!', 'Mckenzie', 'Expectations', 'Lonely Nights',
#        'Sidelines', 'Real Love', 'Angel', 'Harness The Wind',
#        "I'M Just A Clown", 'Dance Around It', 'Pharmacist', 'Lucky Ones',
#        'German Cars', 'Night Moves', 'Run Away', 'If I Die Tomorrow',
#        'I Was Born To Love You', "I'm On Your Side", 'Hard Working Man',
#        'Bad Love', 'Petrified In Love', 'Big Time', 'Problem With It',
#        'Swear Jar', 'Falling Apart (Right Now)', 'Love Me More',
#        'Hi-Fidelity', 'Goodbye, Mr. Blue', 'Puffer', 'Annabelle'],
#       dtype=object)
